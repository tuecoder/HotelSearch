# %% [markdown]
# # Exploratory Data Analysis
# Outline data distributions and quality checks.

# %%
import pandas as pd

hotel_info_df = pd.read_csv('D:/sem3/HotelSearch/data/raw/hotels.csv', encoding='ISO-8859-1')

# %%
hotel_info_df.columns
# Out:
# Index(['countyCode', ' countyName', ' cityCode', ' cityName', ' HotelCode',
#        ' HotelName', ' HotelRating', ' Address', ' Attractions',
#        ' Description', ' FaxNumber', ' HotelFacilities', ' Map',
#        ' PhoneNumber', ' PinCode', ' HotelWebsiteUrl'],
#       dtype='object')

# %%
hotel_info_df[' Description'][3]
# Out:
# "This hotel enjoys an enviable setting in Tirana. The hotel is situated within easy access of a number of the city's most prominent attractions, including the National Bank of Albania, National Museum of History, Skanderbeg Square, the Ministry of Economy, Trade and Energy and the Palace of Culture. Guests are afforded an insight into the rich culture and history of the area. This charming hotel is draped in traditional style, beautifully coupling it with contemporary convenience. The guest rooms are beautifully appointed, featuring muted tones and a peaceful ambience. Those travelling for work purposes will appreciate the excellent business facilities that the hotel has to offer."

# %%
hotel_info_df[hotel_info_df[' countyName'] == 'Netherlands'][' cityName'].unique()
# Out:
# <StringArray>
# [ ''s Gravenmoer', ''s-Gravenzande',  's-Heerenberg',         'Aalden',
#        'Aalsmeer',         'Aalten',     'Aardenburg',   'Aarle-Rixtel',
#         'Abcoude',         'Aduard',
#  ...
#        'Zuidland',      'Zuidlaren',      'Zuidwolde',      'Zuidzande',
#         'Zundert',        'Zutphen',     'Zwanenburg',     'Zwartsluis',
#     'Zwijndrecht',         'Zwolle']
# Length: 619, dtype: str

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("D:/sem3/HotelSearch")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.query_understanding.preprocessing import _step2_spell_correct

# Test cases
tests = [
    "amsterdam 2 adults from 24th June to 26th July with wifi and swimming pool",
    "barselona hotel",
    "swiming pool",
    "Amstrdam",
    "famly frindly hotel",
]

for t in tests:
    print(f"{t!r:35} → {_step2_spell_correct(t)!r}")
# Out:
# 'amsterdam 2 adults from 24th June to 26th July with wifi and swimming pool' → 'amsterdam 2 adults from 24th June to 26th July with wifi and swimming pool'
# 'barselona hotel'                   → 'barcelona hotel'
# 'swiming pool'                      → 'swimming pool'
# 'Amstrdam'                          → 'amsterdam'
# 'famly frindly hotel'               → 'family friendly hotel'

# %%
from nltk.tokenize import word_tokenize

sentence = 'amsterdam 2 adults from 24th june to 26th july with wifi'

tokens = []

for i in sentence.split(" "):
    print(word_tokenize(i))
# Out:
# ['amsterdam']
# ['2']
# ['adults']
# ['from']
# ['24th']
# ['june']
# ['to']
# ['26th']
# ['july']
# ['with']
# ['wifi']

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Amsterdam 2 adults from 24th June to 26th July with wifi")

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Amsterdam 2 ORG
# 24th June to 26th July DATE

# %%
import pandas as pd

df_nl = pd.read_csv('../data/raw/hotels.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df_nl = pd.read_csv('../data/raw/hotels.csv')
#
# File d:\sem3\HotelSearch\hotelenv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_nl.head()
# Out:
#     countyName        cityName                               HotelName  \
# 0  Netherlands   's Gravenmoer  Hotel Restaurant Hof van 's Gravenmoer
# 1  Netherlands  's-Gravenzande    Duynparc de Heeren van S-Gravensande
# 2  Netherlands  's-Gravenzande                             Vlugtenburg
# 3  Netherlands  's-Gravenzande                         Hotel De Gravin
# 4  Netherlands  's-Gravenzande                       De Staelduinhoeve
#
#   HotelRating                                            Address Attractions  \
# 0   ThreeStar  Hoofdstraat 71 5109 AB 's GravenmoerNordbraban...         NaN
# 1   ThreeStar         Nieuwlandsedijk 16 2691 KW  s-Gravenzande         NaN
# 2         All               'T Louwtje 10 2691 KR 'S-Gravenzande         NaN
# 3         All              Monsterseweg 5 2691 JA 's-Gravenzande         NaN
# 4         All                 Maasdijk 172 2691 NX S-Gravenzande         NaN
#
#                                          Description   FaxNumber  \
# ...
